# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import pandas as pd
import numpy as np
import datetime
from pandas_summary import DataFrameSummary

# %%
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_feather('train_normalized_data.fth')
df_test = pd.read_feather('test_normalized_data.fth')

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen', 'Promo2Weeks', 
            'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 
            'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw', 'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw']

cat_vars = ['Store', 'DayOfWeek']

# %%
contin_vars = ['CompetitionDistance', 
   'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Promo', 'SchoolHoliday', 'StateHoliday_bool']
contin_vars = ['BeforeStateHoliday_bool', 'Max_TemperatureC']

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]

# %%
uniques.T
# Out:
#           uniques
# Store        1115
# DayOfWeek       7

# %% [markdown]
# # Asignación de dimensión de embeddings

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 2, 'Year': 2, 'Month': 2,
'Day': 10, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
'Week': 25, 'Events': 4, 'Promo_fw': 1,
'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
'SchoolHoliday_bw': 1}

# %%
for v in cat_vars:
    uniques_ = df[v].unique()
    uniques_.sort()
    print(v, cat_var_dict[v], len(uniques_), uniques_)
    print()
# Out:
# Store 50 1115 [   0    1    2 ... 1112 1113 1114]
#
# DayOfWeek 2 7 [0 1 2 3 4 5 6]

# %% [markdown]
# # Definición de modelo

# %%
add_customers = True
log_output = True
output_activation = 'linear'

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2

# %%
def get_cat_vars_model(cat_vars, uniques, cat_var_dict):
    cat_vars_embed_outs = []
    cat_var_inputs = []
    for cat_var in cat_vars:
        cat_var_in = Input(shape=(1,), name=f"{cat_var}_input")
        cat_var_inputs.append(cat_var_in)
        embed_out = Embedding(uniques[cat_var][0], cat_var_dict[cat_var], name=f'{cat_var}_Embed')(cat_var_in)
        flatten_out = Flatten(name=f"{cat_var}_flat")(embed_out)
        cat_vars_embed_outs.append(flatten_out)
    return cat_var_inputs, cat_vars_embed_outs

def get_cont_vars_input(contin_vars, dense_layer=False):
    cont_vars_inputs = []
    cont_vars_outputs = []
    for cont_var in contin_vars:
        cont_var_in = Input(shape=(1,), name=f"{cont_var}_input")
        cont_vars_inputs.append(cont_var_in)
        if dense_layer:
            cont_var_out = Dense(1, name=f"{cont_var}_input", activation = 'linear')(cont_var_in)
            cont_vars_outputs.append(cont_var_out)
        else:
            cont_vars_outputs.append(cont_var_in)
    return cont_vars_inputs, cont_vars_outputs

# %%
cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model(cat_vars, uniques, cat_var_dict)
cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars)

# %%
# Descomentar para ver resultados
# cat_vars_embed_outs
# cat_var_inputs
# cont_vars_inputs
# cont_vars_outs

# %%
first_hidden_units = 1000
second_hidden_units = 500
l2_lambda = 1e-3
merged = Concatenate(name='All_Concatenate')(cat_vars_embed_outs + cont_vars_inputs)
x = Dense(first_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(merged)
x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)
x = Dense(second_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)

output_1 = Dense(1, name='Sales', activation=output_activation)(x)
output_2 = Dense(1, name='Customers', activation=output_activation)(x)

# %%
if add_customers:
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1, output_2])
else: 
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1])

# %%
# Descomentar para ver
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Store_input (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# DayOfWeek_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Store_Embed (Embedding)         (None, 1, 50)        55750       Store_input[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_Embed (Embedding)     (None, 1, 2)         14          DayOfWeek_input[0][0]
# __________________________________________________________________________________________________
# Store_flat (Flatten)            (None, 50)           0           Store_Embed[0][0]
# __________________________________________________________________________________________________
# DayOfWeek_flat (Flatten)        (None, 2)            0           DayOfWeek_Embed[0][0]
# __________________________________________________________________________________________________
# BeforeStateHoliday_bool_input ( [(None, 1)]          0
# __________________________________________________________________________________________________
# Max_TemperatureC_input (InputLa [(None, 1)]          0
# __________________________________________________________________________________________________
# All_Concatenate (Concatenate)   (None, 54)           0           Store_flat[0][0]
#                                                                  DayOfWeek_flat[0][0]
#                                                                  BeforeStateHoliday_bool_input[0][
#                                                                  Max_TemperatureC_input[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1000)         55000       All_Concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1000)         4000        dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1000)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 500)          500500      activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 500)          2000        dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 500)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# Sales (Dense)                   (None, 1)            501         activation_1[0][0]
# __________________________________________________________________________________________________
# Customers (Dense)               (None, 1)            501         activation_1[0][0]
# ==================================================================================================
# Total params: 618,266
# Trainable params: 615,266
# Non-trainable params: 3,000
# __________________________________________________________________________________________________

# %%
model.save_weights('initial_weights.hdf5')

# %%
df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]
print(f'Cantidad en val: {len(df_val)}, porcentaje: {len(df_train)/(len(df_train) + len(df_val))}')
# Out:
# Cantidad en val: 30188, porcentaje: 0.9642465458145908

# %%
from matplotlib import pyplot as plt
# plt.figure(figsize=(20,5))
# plt.plot((df_train[df_train['Store']==1]['Sales'].values - df_train[df_train['Store']==1]['Sales'].mean())/df_train[df_train['Store']==1]['Sales'].std())
# plt.show()
# plt.figure(figsize=(20,5))
# plt.plot(np.log(df_train[df_train['Store']==1]['Sales'].values)/np.max(np.log(df_train[df_train['Store']==1]['Sales'].values)))
# plt.show()

# %%
stores_mean = {}
for store, g_df in df_train.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_train.loc[:, 'mean_by_store'] = df_train['Store'].apply(stores_mean.get)
df_val.loc[:, 'mean_by_store'] = df_val['Store'].apply(stores_mean.get)

df_train.loc[:, 'Sales_store'] = df_train['Sales'] - df_train['mean_by_store']
df_val.loc[:, 'Sales_store'] = df_val['Sales'] - df_val['mean_by_store']
# Out:
# /Users/matias/opt/anaconda3/envs/deep_learning/lib/python3.6/site-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/matias/opt/anaconda3/envs/deep_learning/lib/python3.6/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
from tensorflow.keras import backend as K

# %%
def rmspe(y_true, y_pred):
    return K.sqrt(K.mean(K.square((y_true - y_pred)/y_true)))

# %%
def get_metric(df, sales_):
    return np.sqrt((((df['Sales'] - sales_)/df['Sales'])**2).mean())

# %%
get_metric(df_val, df_val['mean_by_store'])
# Out:
# 0.3071746085338871

# %%
all_vars = cat_vars + contin_vars
X_train = np.hsplit(df_train[all_vars].values, len(all_vars))
X_val = np.hsplit(df_val[all_vars].values, len(all_vars))
X_test = np.hsplit(df_test[all_vars].values, len(all_vars))

# %%
if add_customers:
    y_out_columns = ['Sales', 'Customers']
else:
    y_out_columns = ['Sales_store']
    
if log_output:
    # Escala logaritmica
    max_log_y = np.max(np.log(df[y_out_columns])).values
    y_train = np.log(df_train[y_out_columns].values)/max_log_y
    y_val = np.log(df_val[y_out_columns].values)/max_log_y
else:
    # Normalización
    y_mean = df_train[y_out_columns].mean().values
    y_std = df_train[y_out_columns].std().values
    y_train = (df_train[y_out_columns].values - y_mean)/y_std
    y_val = (df_val[y_out_columns].values - y_mean)/y_std
    y_max = df_train[y_out_columns].max().values
    y_train = df_train[y_out_columns].values/y_max
    y_val = df_val[y_out_columns].values/y_max
y_train = np.hsplit(y_train, y_train.shape[1])
y_val = np.hsplit(y_val, y_val.shape[1])

# %%
lr = 0.001
model.compile(optimizer=Adam(lr=lr), metrics=['mse', rmspe], loss='mse')

# %%
if add_customers:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_Sales_mse', verbose=1, save_best_only=True)
else:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
epochs = 20
batch_size = 256
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),  epochs=epochs, batch_size=batch_size, callbacks=[checkpoint], verbose=2)
# Out:
# Train on 814150 samples, validate on 30188 samples
# Epoch 1/20
#
# Epoch 00001: val_Sales_mse improved from inf to 0.00773, saving model to bestmodel.hdf5
# 814150/814150 - 223s - loss: 0.1629 - Sales_loss: 0.0139 - Customers_loss: 0.0100 - Sales_mse: 0.0139 - Sales_rmspe: 0.0723 - Customers_mse: 0.0100 - Customers_rmspe: 0.0777 - val_loss: 0.0305 - val_Sales_loss: 0.0077 - val_Customers_loss: 0.0090 - val_Sales_mse: 0.0077 - val_Sales_rmspe: 0.0990 - val_Customers_mse: 0.0090 - val_Customers_rmspe: 0.1148
# Epoch 2/20
#
# Epoch 00002: val_Sales_mse did not improve from 0.00773
# 814150/814150 - 252s - loss: 0.0100 - Sales_loss: 0.0025 - Customers_loss: 0.0023 - Sales_mse: 0.0025 - Sales_rmspe: 0.0589 - Customers_mse: 0.0023 - Customers_rmspe: 0.0641 - val_loss: 0.0158 - val_Sales_loss: 0.0118 - val_Customers_loss: 0.0019 - val_Sales_mse: 0.0118 - val_Sales_rmspe: 0.1298 - val_Customers_mse: 0.0019 - val_Customers_rmspe: 0.0583
# Epoch 3/20
#
# Epoch 00003: val_Sales_mse improved from 0.00773 to 0.00053, saving model to bestmodel.hdf5
# 814150/814150 - 289s - loss: 0.0041 - Sales_loss: 0.0015 - Customers_loss: 0.0013 - Sales_mse: 0.0015 - Sales_rmspe: 0.0456 - Customers_mse: 0.0013 - Customers_rmspe: 0.0477 - val_loss: 0.0017 - val_Sales_loss: 5.3521e-04 - val_Customers_loss: 3.3265e-04 - val_Sales_mse: 5.3494e-04 - val_Sales_rmspe: 0.0265 - val_Customers_mse: 3.3265e-04 - val_Customers_rmspe: 0.0247
# Epoch 4/20
#
# Epoch 00004: val_Sales_mse did not improve from 0.00053
# 814150/814150 - 266s - loss: 0.0025 - Sales_loss: 9.3075e-04 - Customers_loss: 8.7739e-04 - Sales_mse: 9.3075e-04 - Sales_rmspe: 0.0369 - Customers_mse: 8.7720e-04 - Customers_rmspe: 0.0403 - val_loss: 0.0016 - val_Sales_loss: 6.7746e-04 - val_Customers_loss: 3.3696e-04 - val_Sales_mse: 6.7767e-04 - val_Sales_rmspe: 0.0296 - val_Customers_mse: 3.3698e-04 - val_Customers_rmspe: 0.0250
# Epoch 5/20
#
# Epoch 00005: val_Sales_mse improved from 0.00053 to 0.00053, saving model to bestmodel.hdf5
# 814150/814150 - 308s - loss: 0.0018 - Sales_loss: 7.1504e-04 - Customers_loss: 6.5320e-04 - Sales_mse: 7.1505e-04 - Sales_rmspe: 0.0326 - Customers_mse: 6.5324e-04 - Customers_rmspe: 0.0350 - val_loss: 0.0011 - val_Sales_loss: 5.2714e-04 - val_Customers_loss: 3.2372e-04 - val_Sales_mse: 5.2681e-04 - val_Sales_rmspe: 0.0263 - val_Customers_mse: 3.2374e-04 - val_Customers_rmspe: 0.0244
# Epoch 6/20
#
# Epoch 00006: val_Sales_mse improved from 0.00053 to 0.00041, saving model to bestmodel.hdf5
# 814150/814150 - 358s - loss: 0.0011 - Sales_loss: 5.3641e-04 - Customers_loss: 4.2483e-04 - Sales_mse: 5.3638e-04 - Sales_rmspe: 0.0284 - Customers_mse: 4.2482e-04 - Customers_rmspe: 0.0286 - val_loss: 7.3893e-04 - val_Sales_loss: 4.1328e-04 - val_Customers_loss: 2.9947e-04 - val_Sales_mse: 4.1315e-04 - val_Sales_rmspe: 0.0243 - val_Customers_mse: 2.9943e-04 - val_Customers_rmspe: 0.0236
# Epoch 7/20
#
# Epoch 00007: val_Sales_mse did not improve from 0.00041
# 814150/814150 - 366s - loss: 9.2518e-04 - Sales_loss: 5.0732e-04 - Customers_loss: 3.9429e-04 - Sales_mse: 5.0731e-04 - Sales_rmspe: 0.0276 - Customers_mse: 3.9429e-04 - Customers_rmspe: 0.0276 - val_loss: 9.0050e-04 - val_Sales_loss: 5.4867e-04 - val_Customers_loss: 3.2819e-04 - val_Sales_mse: 5.4839e-04 - val_Sales_rmspe: 0.0265 - val_Customers_mse: 3.2816e-04 - val_Customers_rmspe: 0.0246
# Epoch 8/20
#
# Epoch 00008: val_Sales_mse improved from 0.00041 to 0.00039, saving model to bestmodel.hdf5
# 814150/814150 - 374s - loss: 9.1839e-04 - Sales_loss: 5.0140e-04 - Customers_loss: 3.9217e-04 - Sales_mse: 5.0140e-04 - Sales_rmspe: 0.0275 - Customers_mse: 3.9217e-04 - Customers_rmspe: 0.0276 - val_loss: 7.4412e-04 - val_Sales_loss: 3.8683e-04 - val_Customers_loss: 3.3096e-04 - val_Sales_mse: 3.8679e-04 - val_Sales_rmspe: 0.0236 - val_Customers_mse: 3.3103e-04 - val_Customers_rmspe: 0.0246
# Epoch 9/20
#
# Epoch 00009: val_Sales_mse improved from 0.00039 to 0.00039, saving model to bestmodel.hdf5
# 814150/814150 - 303s - loss: 9.0667e-04 - Sales_loss: 4.9472e-04 - Customers_loss: 3.8589e-04 - Sales_mse: 4.9473e-04 - Sales_rmspe: 0.0273 - Customers_mse: 3.8587e-04 - Customers_rmspe: 0.0274 - val_loss: 7.9413e-04 - val_Sales_loss: 3.8694e-04 - val_Customers_loss: 3.8127e-04 - val_Sales_mse: 3.8674e-04 - val_Sales_rmspe: 0.0237 - val_Customers_mse: 3.8137e-04 - val_Customers_rmspe: 0.0260
# Epoch 10/20
#
# Epoch 00010: val_Sales_mse did not improve from 0.00039
# 814150/814150 - 292s - loss: 8.9290e-04 - Sales_loss: 4.8688e-04 - Customers_loss: 3.7872e-04 - Sales_mse: 4.8686e-04 - Sales_rmspe: 0.0271 - Customers_mse: 3.7871e-04 - Customers_rmspe: 0.0271 - val_loss: 0.0011 - val_Sales_loss: 6.6989e-04 - val_Customers_loss: 4.1973e-04 - val_Sales_mse: 6.6943e-04 - val_Sales_rmspe: 0.0292 - val_Customers_mse: 4.1956e-04 - val_Customers_rmspe: 0.0270
# Epoch 11/20
#
# Epoch 00011: val_Sales_mse improved from 0.00039 to 0.00037, saving model to bestmodel.hdf5
# 814150/814150 - 530s - loss: 8.8482e-04 - Sales_loss: 4.8379e-04 - Customers_loss: 3.7431e-04 - Sales_mse: 4.8374e-04 - Sales_rmspe: 0.0270 - Customers_mse: 3.7428e-04 - Customers_rmspe: 0.0269 - val_loss: 7.6451e-04 - val_Sales_loss: 3.6811e-04 - val_Customers_loss: 3.7049e-04 - val_Sales_mse: 3.6797e-04 - val_Sales_rmspe: 0.0231 - val_Customers_mse: 3.7059e-04 - val_Customers_rmspe: 0.0259
# Epoch 12/20
#
# Epoch 00012: val_Sales_mse did not improve from 0.00037
# 814150/814150 - 209s - loss: 8.8357e-04 - Sales_loss: 4.8304e-04 - Customers_loss: 3.7487e-04 - Sales_mse: 4.8301e-04 - Sales_rmspe: 0.0270 - Customers_mse: 3.7486e-04 - Customers_rmspe: 0.0269 - val_loss: 8.0890e-04 - val_Sales_loss: 4.2724e-04 - val_Customers_loss: 3.5596e-04 - val_Sales_mse: 4.2730e-04 - val_Sales_rmspe: 0.0236 - val_Customers_mse: 3.5606e-04 - val_Customers_rmspe: 0.0251
# Epoch 13/20
#
# Epoch 00013: val_Sales_mse did not improve from 0.00037
# 814150/814150 - 273s - loss: 8.8344e-04 - Sales_loss: 4.8371e-04 - Customers_loss: 3.7444e-04 - Sales_mse: 4.8371e-04 - Sales_rmspe: 0.0270 - Customers_mse: 3.7443e-04 - Customers_rmspe: 0.0269 - val_loss: 7.7523e-04 - val_Sales_loss: 3.7348e-04 - val_Customers_loss: 3.7554e-04 - val_Sales_mse: 3.7343e-04 - val_Sales_rmspe: 0.0231 - val_Customers_mse: 3.7564e-04 - val_Customers_rmspe: 0.0258
# Epoch 14/20
#
# Epoch 00014: val_Sales_mse did not improve from 0.00037
# 814150/814150 - 353s - loss: 8.7904e-04 - Sales_loss: 4.8130e-04 - Customers_loss: 3.7290e-04 - Sales_mse: 4.8128e-04 - Sales_rmspe: 0.0269 - Customers_mse: 3.7287e-04 - Customers_rmspe: 0.0269 - val_loss: 0.0011 - val_Sales_loss: 4.3241e-04 - val_Customers_loss: 6.1554e-04 - val_Sales_mse: 4.3245e-04 - val_Sales_rmspe: 0.0245 - val_Customers_mse: 6.1578e-04 - val_Customers_rmspe: 0.0328
# Epoch 15/20
#
# Epoch 00015: val_Sales_mse did not improve from 0.00037
# 814150/814150 - 312s - loss: 8.7791e-04 - Sales_loss: 4.8145e-04 - Customers_loss: 3.7207e-04 - Sales_mse: 4.8145e-04 - Sales_rmspe: 0.0269 - Customers_mse: 3.7207e-04 - Customers_rmspe: 0.0269 - val_loss: 7.0660e-04 - val_Sales_loss: 3.8535e-04 - val_Customers_loss: 2.9708e-04 - val_Sales_mse: 3.8513e-04 - val_Sales_rmspe: 0.0233 - val_Customers_mse: 2.9712e-04 - val_Customers_rmspe: 0.0233
# Epoch 16/20
#
# Epoch 00016: val_Sales_mse improved from 0.00037 to 0.00035, saving model to bestmodel.hdf5
# 814150/814150 - 326s - loss: 8.7733e-04 - Sales_loss: 4.8134e-04 - Customers_loss: 3.7188e-04 - Sales_mse: 4.8134e-04 - Sales_rmspe: 0.0269 - Customers_mse: 3.7188e-04 - Customers_rmspe: 0.0268 - val_loss: 6.5078e-04 - val_Sales_loss: 3.5190e-04 - val_Customers_loss: 2.7556e-04 - val_Sales_mse: 3.5176e-04 - val_Sales_rmspe: 0.0225 - val_Customers_mse: 2.7557e-04 - val_Customers_rmspe: 0.0225
# Epoch 17/20
#
# Epoch 00017: val_Sales_mse did not improve from 0.00035
# 814150/814150 - 298s - loss: 8.7563e-04 - Sales_loss: 4.8016e-04 - Customers_loss: 3.7154e-04 - Sales_mse: 4.8016e-04 - Sales_rmspe: 0.0269 - Customers_mse: 3.7153e-04 - Customers_rmspe: 0.0268 - val_loss: 6.9049e-04 - val_Sales_loss: 3.6122e-04 - val_Customers_loss: 3.0462e-04 - val_Sales_mse: 3.6112e-04 - val_Sales_rmspe: 0.0228 - val_Customers_mse: 3.0465e-04 - val_Customers_rmspe: 0.0235
# Epoch 18/20
#
# Epoch 00018: val_Sales_mse did not improve from 0.00035
# 814150/814150 - 380s - loss: 8.7273e-04 - Sales_loss: 4.7889e-04 - Customers_loss: 3.7040e-04 - Sales_mse: 4.7888e-04 - Sales_rmspe: 0.0268 - Customers_mse: 3.7040e-04 - Customers_rmspe: 0.0268 - val_loss: 7.0296e-04 - val_Sales_loss: 3.6410e-04 - val_Customers_loss: 3.1572e-04 - val_Sales_mse: 3.6404e-04 - val_Sales_rmspe: 0.0228 - val_Customers_mse: 3.1576e-04 - val_Customers_rmspe: 0.0239
# Epoch 19/20
#
# Epoch 00019: val_Sales_mse did not improve from 0.00035
# 814150/814150 - 333s - loss: 8.7208e-04 - Sales_loss: 4.7913e-04 - Customers_loss: 3.6975e-04 - Sales_mse: 4.7913e-04 - Sales_rmspe: 0.0268 - Customers_mse: 3.6975e-04 - Customers_rmspe: 0.0268 - val_loss: 7.0263e-04 - val_Sales_loss: 3.7013e-04 - val_Customers_loss: 3.0883e-04 - val_Sales_mse: 3.7007e-04 - val_Sales_rmspe: 0.0231 - val_Customers_mse: 3.0888e-04 - val_Customers_rmspe: 0.0237
# Epoch 20/20
#
# Epoch 00020: val_Sales_mse did not improve from 0.00035
# 814150/814150 - 305s - loss: 8.7229e-04 - Sales_loss: 4.7922e-04 - Customers_loss: 3.6988e-04 - Sales_mse: 4.7924e-04 - Sales_rmspe: 0.0268 - Customers_mse: 3.6988e-04 - Customers_rmspe: 0.0268 - val_loss: 6.6149e-04 - val_Sales_loss: 3.5810e-04 - val_Customers_loss: 2.8090e-04 - val_Sales_mse: 3.5797e-04 - val_Sales_rmspe: 0.0228 - val_Customers_mse: 2.8091e-04 - val_Customers_rmspe: 0.0227

# %%
plt.plot(history.history['val_loss'])
# plt.plot(history.history['val_Customers_mse'])
# plt.plot(history.history['val_Sales_mse'])
plt.show()
plt.plot(history.history['loss'])
# plt.plot(history.history['Customers_mse'])
# plt.plot(history.history['Sales_mse'])

# %% [markdown]
# # Métrica

# %% [markdown]
# $$
# \textrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} \left(\frac{\hat{y}_i - y_i}{y_i}\right)^2}
# $$

# %%
model.evaluate(X_val, y_val)
# Out:
# 30188/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.0006614934800016741,
#  0.00035812933,
#  0.00028089582,
#  0.00035797007,
#  0.022534255,
#  0.0002809064,
#  0.022390252]

# %%
model.load_weights('bestmodel.hdf5')
model.evaluate(X_val, y_val)
# Out:
# 30188/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.0006507807992173158,
#  0.0003519407,
#  0.0002755369,
#  0.00035176318,
#  0.022351552,
#  0.00027556974,
#  0.02230874]

# %%
# model.load_weights('bestmodel.hdf5')
# model.evaluate(X_val, y_val)
# 30188/30188 [==============================] - 5s 172us/step
# [0.12197033089921382,
#  0.07211007360268763,
#  0.037183713050426136,
#  0.07211007360268763,
#  0.037183713050426136]

# [0.12932546436786652,
#  0.07751645147800446,
#  0.039259567856788635,
#  0.07751645147800446,
#  0.039259567856788635]

# %%
if log_output:
    if add_customers:
        y_pred = np.exp(model.predict(X_val, verbose=1)[0][:, 0]*max_log_y[0])
        y_pred_test = np.exp(model.predict(X_test, verbose=1)[0][:, 0]*max_log_y[0])
    else:
        y_pred = np.exp(model.predict(X_val, verbose=1)*max_log_y)[:,0]
        y_pred_test = np.exp(model.predict(X_test, verbose=1)*max_log_y)[:,0]
else:
    if add_customers:
        y_pred = (model.predict(X_val, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
        y_pred_test = (model.predict(X_test, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
    else:
#         y_pred = model.predict(X_val, verbose=1)[:,0]*y_std + y_mean
#         y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_std + y_mean
        y_pred = model.predict(X_val, verbose=1)[:,0]*y_max
        y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_max
y_pred_test[df_test['Open'] == 0] = 0
# Out:
# 30188/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 41088/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
np.sqrt((((df_val['Sales'].values - y_pred)/df_val['Sales'].values)**2).sum()/len(y_pred))
# Out:
# 0.20522261041898227

# %%
y_pred_test[:10]
# Out:
# array([4866.5703, 6924.17  , 8898.223 , 5544.8164, 6684.888 , 5773.67  ,
#        8155.982 , 7355.1733, 4560.1807, 5801.012 ], dtype=float32)

# %% [markdown]
# # Baseline

# %%
import pandas as pd
sample_csv = pd.read_csv('dataset/rossmann/sample_submission.csv')

# %%
stores_mean = {}
for store, g_df in df.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_test['Sales'] = df_test['Store'].apply(stores_mean.get)
df_test.loc[df_test['Open'] == 0, 'Sales'] = 0

# %%
df_test[['Store', 'Sales']].head(10)
# Out:
#    Store        Sales
# 0      0  4759.096031
# 1      2  6942.568678
# 2      6  8817.050891
# 3      7  5539.358418
# 4      8  6562.337612
# 5      9  5568.420918
# 6     10  8030.977041
# 7     11  7589.598214
# 8     12  5034.747182
# 9     13  5508.567394

# %%
df_test[df_test['Open'] == 0][['Store', 'Sales']].head()
# Out:
#       Store  Sales
# 543     702    0.0
# 676     878    0.0
# 840    1096    0.0
# 1399    702    0.0
# 1532    878    0.0

# %%
sample_csv['Sales'] = df_test['Sales']

# %%
sample_csv.to_csv(f'submision_baseline.csv', index=False)

# %%
sample_csv.head()
# Out:
#    Id        Sales
# 0   1  4759.096031
# 1   2  6942.568678
# 2   3  8817.050891
# 3   4  5539.358418
# 4   5  6562.337612

# %% [markdown]
# # Sumbit a la competición

# %%
sample_csv = pd.read_csv('dataset/rossmann/sample_submission.csv')
sample_csv['Sales'] = y_pred_test
sample_csv.head()

sample_csv.to_csv(f'submision_{add_customers}-{log_output}-{output_activation}-{l2_lambda}-{first_hidden_units}-{epochs}-{batch_size}-{lr}.csv', index=False)

# %% [markdown]
# # Analisis de embedings

# %%
def plot_embed(layer_name, cat_names):
    Y = model.get_layer(layer_name).get_weights()[0]
    print(Y.shape)
    plt.figure(figsize=(8,8))
    plt.scatter(-Y[:, 0], -Y[:, 1])
    for i, txt in enumerate(cat_names):
        plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
model.load_weights('bestmodel.hdf5')
plot_embed('DayOfWeek_Embed', ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun'])
# Out:
# (7, 2)

# %%
plot_embed('Month_Embed', list(range(12)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-c3dc3ee5fed0> in <module>
# ----> 1 plot_embed('Month_Embed', list(range(12)))
#
# <ipython-input-51-52ee9a3c03b6> in plot_embed(layer_name, cat_names)
#       1 def plot_embed(layer_name, cat_names):
# ----> 2     Y = model.get_layer(layer_name).get_weights()[0]
#       3     print(Y.shape)
#       4     plt.figure(figsize=(8,8))
#       5     plt.scatter(-Y[:, 0], -Y[:, 1])
#
# ~/opt/anaconda3/envs/deep_learning/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in get_layer(self, name, index)
#     537       if layer.name == name:
#     538         return layer
# --> 539     raise ValueError('No such layer: ' + name)
#     540
#     541   @property
#
# ValueError: No such layer: Month_Embed

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
day_of_week_embedding.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-00f84f4b7b18> in <module>
# ----> 1 day_of_week_embedding.shape
#
# NameError: name 'day_of_week_embedding' is not defined

# %%
tsne = TSNE(n_components=2, random_state=1, learning_rate=10, n_iter=10000)
Y = tsne.fit_transform(day_of_week_embedding)
names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-05f8c2c9edfa> in <module>
#       1 tsne = TSNE(n_components=2, random_state=1, learning_rate=10, n_iter=10000)
# ----> 2 Y = tsne.fit_transform(day_of_week_embedding)
#       3 names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
#       4 plt.figure(figsize=(8,8))
#       5 plt.scatter(-Y[:, 0], -Y[:, 1])
#
# NameError: name 'day_of_week_embedding' is not defined

# %%
cat_vars
# Out:
# ['Store', 'DayOfWeek']

# %% [markdown]
# ## Store embeddings

# %%
submodel = Model(cat_var_inputs + cont_vars_inputs, merged)

# %%
submodel.summary()

# %%
submodel.save('embeddings_model.hdf5')
